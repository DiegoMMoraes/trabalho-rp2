# %%
import pandas as pd

df = pd.read_csv('../Dados_Saeb_2021/DADOS/dados_final_binario.csv')
# PROFICIENCIA_LP_SAEB,PROFICIENCIA_MT_SAEB
print(min(df['PROFICIENCIA_LP_SAEB']))
print(max(df['PROFICIENCIA_LP_SAEB']))
print(min(df['PROFICIENCIA_MT_SAEB']))
print(max(df['PROFICIENCIA_MT_SAEB']))
# Out:
# 143.088605
# 407.572557
# 147.580927
# 438.574383
